# %% [markdown]
# # find a website where you can pass parms ,header and auth

# %%
import requests as rq
url = 'https://api.openaq.org/v2/countries'
Resp = rq.get(url)
Resp
<Response [200]>
print(Resp.content.decode('utf-8'))

# %% [raw]
# {"meta":{"name":"openaq-api","license":"","website":"/","page":1,"limit":100,"found":">100"},"results":[{"code":"AF","name":"Afghanistan","locations":2,"firstUpdated":"2019-10-20 22:30:00+00","lastUpdated":"2021-08-16 18:00:00+00","parameters":["pm25"],"count":23640,"cities":1,"sources":2},{"code":"DZ","name":"Algeria","locations":1,"firstUpdated":"2019-06-15 22:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":38662,"cities":1,"sources":1},{"code":"AQ","name":"Antarctica","locations":2,"firstUpdated":"2018-11-30 11:00:00+00","lastUpdated":"2021-02-04 14:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":9180,"cities":0,"sources":2},{"code":"AR","name":"Argentina","locations":16,"firstUpdated":"2016-01-01 03:00:00+00","lastUpdated":"2024-05-29 03:00:00+00","parameters":["co","no","no2","nox","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":286883,"cities":1,"sources":6},{"code":"AM","name":"Armenia","locations":1,"firstUpdated":"2022-11-14 08:00:00+00","lastUpdated":"2023-06-15 11:00:00+00","parameters":["pm25"],"count":1284,"cities":1,"sources":1},{"code":"AU","name":"Australia","locations":244,"firstUpdated":"2016-01-28 19:00:00+00","lastUpdated":"2024-05-28 13:54:09+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":13877179,"cities":55,"sources":10},{"code":"AT","name":"Austria","locations":374,"firstUpdated":"2016-11-18 05:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":13407900,"cities":162,"sources":4},{"code":"AZ","name":"Azerbaijan","locations":1,"firstUpdated":"2022-06-23 12:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":12789,"cities":1,"sources":1},{"code":"BD","name":"Bangladesh","locations":4,"firstUpdated":"2016-03-10 22:00:00+00","lastUpdated":"2024-05-28 04:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":139553,"cities":1,"sources":2},{"code":"BE","name":"Belgium","locations":173,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":4758806,"cities":77,"sources":6},{"code":"BZ","name":"Belize","locations":1,"firstUpdated":"2023-03-19 20:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":7957,"cities":1,"sources":1},{"code":"BA","name":"Bosnia and Herz.","locations":47,"firstUpdated":"2016-04-26 21:30:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":1359929,"cities":22,"sources":6},{"code":"BR","name":"Brazil","locations":75,"firstUpdated":"2017-07-01 00:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","humidity","no","no2","nox","o3","pm1","pm10","pm25","pressure","so2","temperature","um003","um005","um010","um025","um050","um100","voc"],"count":3056043,"cities":39,"sources":5},{"code":"BG","name":"Bulgaria","locations":105,"firstUpdated":"2020-04-20 18:00:00+00","lastUpdated":"2024-05-28 06:43:00+00","parameters":["co","humidity","no","no2","o3","pm1","pm10","pm25","pm4","pressure","so2","temperature"],"count":126709493,"cities":2,"sources":2},{"code":"CA","name":"Canada","locations":365,"firstUpdated":"2016-03-06 19:00:00+00","lastUpdated":"2024-05-28 06:06:52.2+00","parameters":["co","no","no2","nox","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":18319006,"cities":18,"sources":5},{"code":"TD","name":"Chad","locations":1,"firstUpdated":"2020-08-02 20:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":28988,"cities":1,"sources":1},{"code":"CL","name":"Chile","locations":154,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":10829244,"cities":61,"sources":2},{"code":"CN","name":"China","locations":1873,"firstUpdated":"2016-01-01 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":170585941,"cities":18,"sources":19},{"code":"CO","name":"Colombia","locations":60,"firstUpdated":"2016-03-17 15:00:00+00","lastUpdated":"2024-05-28 06:05:50.659+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":2415794,"cities":10,"sources":5},{"code":"CR","name":"Costa Rica","locations":1,"firstUpdated":"2019-10-28 18:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["pm25"],"count":33113,"cities":1,"sources":1},{"code":"CI","name":"Côte d'Ivoire","locations":1,"firstUpdated":"2020-03-15 21:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["pm25"],"count":29730,"cities":1,"sources":1},{"code":"HR","name":"Croatia","locations":27,"firstUpdated":"2016-11-17 22:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":1502388,"cities":16,"sources":3},{"code":"CY","name":"Cyprus","locations":11,"firstUpdated":"2020-04-20 16:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","nox","o3","pm10","pm25","so2"],"count":647894,"cities":11,"sources":2},{"code":"CZ","name":"Czechia","locations":124,"firstUpdated":"2016-11-21 11:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":11828018,"cities":72,"sources":4},{"code":"CD","name":"Dem. Rep. Congo","locations":1,"firstUpdated":"2022-06-16 16:00:00+00","lastUpdated":"2024-05-04 13:00:00+00","parameters":["pm25"],"count":3794,"cities":1,"sources":1},{"code":"DK","name":"Denmark","locations":15,"firstUpdated":"2016-11-21 11:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no","no2","o3","pm10","pm25","so2","temperature"],"count":1045065,"cities":9,"sources":3},{"code":"EC","name":"Ecuador","locations":10,"firstUpdated":"2020-12-29 05:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":93253,"cities":0,"sources":2},{"code":"EG","name":"Egypt","locations":2,"firstUpdated":"2022-06-20 18:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":10861,"cities":1,"sources":1},{"code":"EE","name":"Estonia","locations":7,"firstUpdated":"2020-04-20 20:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":256656,"cities":5,"sources":1},{"code":"ET","name":"Ethiopia","locations":3,"firstUpdated":"2016-08-18 22:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["pm25"],"count":113762,"cities":2,"sources":2},{"code":"FI","name":"Finland","locations":81,"firstUpdated":"2016-12-10 19:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["no2","o3","pm10","pm25","so2"],"count":4440193,"cities":32,"sources":2},{"code":"FR","name":"France","locations":793,"firstUpdated":"2016-11-17 23:00:00+00","lastUpdated":"2024-05-28 06:06:49.551+00","parameters":["co","humidity","no","no2","o3","pm1","pm10","pm25","pressure","relativehumidity","so2","temperature","um003","um005","um010","um025","um050","um100"],"count":46324429,"cities":418,"sources":8},{"code":"GA","name":"Gabon","locations":1,"firstUpdated":"2021-10-06 12:00:00+00","lastUpdated":"2022-02-27 19:00:00+00","parameters":["pm25"],"count":2828,"cities":0,"sources":1},{"code":"GM","name":"Gambia","locations":1,"firstUpdated":"2022-10-20 01:00:00+00","lastUpdated":"2023-09-15 23:03:55.489+00","parameters":["no2","pm1","pm10","pm25"],"count":12354,"cities":0,"sources":1},{"code":"DE","name":"Germany","locations":511,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":24021710,"cities":291,"sources":4},{"code":"GH","name":"Ghana","locations":12,"firstUpdated":"2020-05-01 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["no2","pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":1168487,"cities":1,"sources":3},{"code":"GR","name":"Greece","locations":52,"firstUpdated":"2020-04-20 18:00:00+00","lastUpdated":"2024-05-28 06:43:00+00","parameters":["co","humidity","no","no2","o3","pm1","pm10","pm25","pm4","pressure","so2","temperature"],"count":7385585,"cities":8,"sources":3},{"code":"GT","name":"Guatemala","locations":2,"firstUpdated":"2019-10-20 21:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["o3","pm10","pm25"],"count":96019,"cities":2,"sources":2},{"code":"GN","name":"Guinea","locations":1,"firstUpdated":"2020-05-01 02:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["pm25"],"count":28397,"cities":1,"sources":1},{"code":"HU","name":"Hungary","locations":97,"firstUpdated":"2016-12-12 14:00:00+00","lastUpdated":"2024-05-28 23:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":5689639,"cities":64,"sources":3},{"code":"IS","name":"Iceland","locations":24,"firstUpdated":"2020-02-28 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":823626,"cities":8,"sources":3},{"code":"IN","name":"India","locations":421,"firstUpdated":"2016-01-30 00:30:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":42137284,"cities":4,"sources":10},{"code":"ID","name":"Indonesia","locations":12,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-28 06:02:03.158+00","parameters":["o3","pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":138396,"cities":3,"sources":7},{"code":"IQ","name":"Iraq","locations":5,"firstUpdated":"2019-03-10 16:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":71150,"cities":3,"sources":3},{"code":"IE","name":"Ireland","locations":45,"firstUpdated":"2016-02-27 21:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":1690166,"cities":5,"sources":3},{"code":"IL","name":"Israel","locations":111,"firstUpdated":"2016-01-01 01:00:00+00","lastUpdated":"2021-11-19 09:00:00+00","parameters":["co","no2","o3","pm25","so2"],"count":19575369,"cities":1,"sources":2},{"code":"IT","name":"Italy","locations":745,"firstUpdated":"2016-11-21 12:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","nox","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":25532895,"cities":608,"sources":8},{"code":"JP","name":"Japan","locations":1539,"firstUpdated":"2023-07-14 17:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no","no2","nox","pm25","so2","temperature"],"count":37753244,"cities":1,"sources":3},{"code":"JO","name":"Jordan","locations":5,"firstUpdated":"2017-08-10 23:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm25","so2"],"count":648734,"cities":2,"sources":3},{"code":"KZ","name":"Kazakhstan","locations":40,"firstUpdated":"2018-07-27 16:00:00+00","lastUpdated":"2024-05-28 06:06:58.383+00","parameters":["pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":139558,"cities":1,"sources":3},{"code":"KE","name":"Kenya","locations":6,"firstUpdated":"2018-04-21 00:00:00+00","lastUpdated":"2024-05-28 05:59:33.775+00","parameters":["pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":20978,"cities":1,"sources":4},{"code":"XK","name":"Kosovo","locations":24,"firstUpdated":"2016-04-08 20:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":608778,"cities":12,"sources":4},{"code":"KW","name":"Kuwait","locations":1,"firstUpdated":"2017-02-17 21:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":54873,"cities":1,"sources":1},{"code":"KG","name":"Kyrgyzstan","locations":47,"firstUpdated":"2019-03-08 20:00:00+00","lastUpdated":"2024-05-28 06:06:40.961+00","parameters":["pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":177563,"cities":2,"sources":4},{"code":"LA","name":"Laos","locations":9,"firstUpdated":"2021-04-29 19:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":226761,"cities":4,"sources":3},{"code":"LV","name":"Latvia","locations":13,"firstUpdated":"2017-09-22 10:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":427349,"cities":5,"sources":2},{"code":"LT","name":"Lithuania","locations":17,"firstUpdated":"2017-09-21 23:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":919075,"cities":13,"sources":2},{"code":"LU","name":"Luxembourg","locations":12,"firstUpdated":"2017-09-22 10:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no","no2","o3","pm10","pm25","so2"],"count":869139,"cities":1,"sources":2},{"code":"MK","name":"Macedonia","locations":28,"firstUpdated":"2016-12-10 20:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no","no2","o3","pm10","pm25","so2"],"count":2965491,"cities":6,"sources":2},{"code":"MG","name":"Madagascar","locations":1,"firstUpdated":"2020-12-22 06:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":21879,"cities":1,"sources":1},{"code":"MY","name":"Malaysia","locations":11,"firstUpdated":"2016-04-05 09:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":114780,"cities":4,"sources":4},{"code":"ML","name":"Mali","locations":1,"firstUpdated":"2020-03-16 05:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":25470,"cities":1,"sources":1},{"code":"MX","name":"Mexico","locations":237,"firstUpdated":"2016-03-06 19:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","nox","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":10839218,"cities":111,"sources":4},{"code":"MD","name":"Moldova","locations":2,"firstUpdated":"2020-04-20 19:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["no2","pm10","pm25","so2"],"count":35328,"cities":2,"sources":2},{"code":"MN","name":"Mongolia","locations":44,"firstUpdated":"2016-01-30 00:15:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":2358918,"cities":22,"sources":3},{"code":"ME","name":"Montenegro","locations":9,"firstUpdated":"2022-03-24 14:00:00+00","lastUpdated":"2024-03-19 22:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":273080,"cities":7,"sources":1},{"code":"MA","name":"Morocco","locations":2,"firstUpdated":"2024-04-04 10:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":8094,"cities":0,"sources":1},{"code":"MZ","name":"Mozambique","locations":1,"firstUpdated":"2024-01-18 18:00:00+00","lastUpdated":"2024-01-22 16:00:00+00","parameters":["o3","pm25"],"count":137,"cities":1,"sources":1},{"code":"MM","name":"Myanmar","locations":5,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":319642,"cities":3,"sources":4},{"code":"NP","name":"Nepal","locations":4,"firstUpdated":"2017-03-02 23:15:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["o3","pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":222045,"cities":1,"sources":2},{"code":"NL","name":"Netherlands","locations":98,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":13074926,"cities":50,"sources":4},{"code":"NZ","name":"New Zealand","locations":12,"firstUpdated":"2023-03-31 15:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":96406,"cities":8,"sources":2},{"code":"NG","name":"Nigeria","locations":5,"firstUpdated":"2019-04-26 08:00:00+00","lastUpdated":"2024-05-28 05:57:43.687+00","parameters":["pm25"],"count":23153,"cities":2,"sources":3},{"code":"KP","name":"North Korea","locations":4,"firstUpdated":"2024-03-20 08:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":28803,"cities":1,"sources":1},{"code":"NO","name":"Norway","locations":354,"firstUpdated":"2016-12-02 10:00:00+00","lastUpdated":"2024-05-28 06:43:00+00","parameters":["bc","co","co2","humidity","no","no2","o3","pm1","pm10","pm25","pm4","pressure","relativehumidity","so2","temperature","um003","um005","um010","um025","um050","um100"],"count":36125380,"cities":27,"sources":5},{"code":"PK","name":"Pakistan","locations":6,"firstUpdated":"2019-05-22 22:00:00+00","lastUpdated":"2024-05-28 05:56:54.739+00","parameters":["pm25"],"count":168011,"cities":3,"sources":4},{"code":"PS","name":"Palestine","locations":9,"firstUpdated":"2017-08-10 23:00:00+00","lastUpdated":"2019-04-03 21:00:00+00","parameters":["co","no2","o3","so2"],"count":1449100,"cities":0,"sources":1},{"code":"PY","name":"Paraguay","locations":1,"firstUpdated":"2023-10-02 19:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["pm25"],"count":5045,"cities":1,"sources":1},{"code":"PE","name":"Peru","locations":46,"firstUpdated":"2016-03-04 17:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":2300920,"cities":21,"sources":5},{"code":"PH","name":"Philippines","locations":5,"firstUpdated":"2023-09-06 20:00:00+00","lastUpdated":"2024-05-28 05:55:42.086+00","parameters":["pm25","temperature"],"count":12313,"cities":1,"sources":3},{"code":"PL","name":"Poland","locations":330,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["bc","co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":25797718,"cities":197,"sources":5},{"code":"PT","name":"Portugal","locations":70,"firstUpdated":"2017-05-11 08:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":6847829,"cities":8,"sources":3},{"code":"PR","name":"Puerto Rico","locations":5,"firstUpdated":"2016-05-04 11:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["o3","pm10","pm25"],"count":99586,"cities":2,"sources":1},{"code":"QA","name":"Qatar","locations":1,"firstUpdated":"2022-04-11 14:00:00+00","lastUpdated":"2023-11-30 08:00:00+00","parameters":["o3","pm25"],"count":16513,"cities":1,"sources":1},{"code":"RO","name":"Romania","locations":318,"firstUpdated":"2020-04-19 21:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":5243956,"cities":109,"sources":4},{"code":"RU","name":"Russia","locations":54,"firstUpdated":"2016-11-21 11:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":560667,"cities":2,"sources":5},{"code":"RW","name":"Rwanda","locations":2,"firstUpdated":"2020-12-28 22:45:00+00","lastUpdated":"2024-05-14 00:00:00+00","parameters":["co","no2","pm10","pm25"],"count":126004,"cities":1,"sources":2},{"code":"SA","name":"Saudi Arabia","locations":5,"firstUpdated":"2019-07-15 19:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no2","pm10","pm25","so2"],"count":21277,"cities":3,"sources":3},{"code":"SN","name":"Senegal","locations":1,"firstUpdated":"2023-09-05 08:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["pm1","pm10","pm25","relativehumidity","temperature","um003"],"count":7082,"cities":0,"sources":1},{"code":"RS","name":"Serbia","locations":85,"firstUpdated":"2017-09-22 09:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2","temperature"],"count":3298862,"cities":44,"sources":5},{"code":"SK","name":"Slovakia","locations":85,"firstUpdated":"2016-11-18 05:00:00+00","lastUpdated":"2024-05-28 05:00:00+00","parameters":["co","no","no2","o3","pm10","pm25","so2"],"count":5924917,"cities":58,"sources":3},{"code":"SI","name":"Slovenia","locations":39,"firstUpdated":"2016-11-17 22:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":786691,"cities":26,"sources":3},{"code":"ZA","name":"South Africa","locations":200,"firstUpdated":"2016-02-14 08:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","nox","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":4685647,"cities":36,"sources":4},{"code":"KR","name":"South Korea","locations":685,"firstUpdated":"2020-10-12 06:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":6144241,"cities":3,"sources":3},{"code":"ES","name":"Spain","locations":738,"firstUpdated":"2016-11-17 23:00:00+00","lastUpdated":"2024-05-28 06:43:00+00","parameters":["co","humidity","no","no2","nox","o3","pm1","pm10","pm25","pm4","pressure","relativehumidity","so2","temperature","um003"],"count":44873956,"cities":351,"sources":7},{"code":"LK","name":"Sri Lanka","locations":1,"firstUpdated":"2019-06-25 21:30:00+00","lastUpdated":"2024-05-27 06:30:00+00","parameters":["pm25"],"count":21792,"cities":1,"sources":1},{"code":"SD","name":"Sudan","locations":3,"firstUpdated":"2020-05-14 14:00:00+00","lastUpdated":"2023-05-17 13:00:00+00","parameters":["pm25"],"count":54546,"cities":2,"sources":3},{"code":"SE","name":"Sweden","locations":170,"firstUpdated":"2016-12-02 11:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm10","pm25","so2"],"count":2532472,"cities":53,"sources":5},{"code":"CH","name":"Switzerland","locations":51,"firstUpdated":"2016-11-21 12:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":3285856,"cities":13,"sources":3},{"code":"TW","name":"Taiwan","locations":91,"firstUpdated":"2016-12-20 19:00:00+00","lastUpdated":"2024-05-28 06:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":8372589,"cities":17,"sources":2}]}

# %% [markdown]
# # Headers

# %%
type(Resp.headers)

lHeader = Resp.headers

print(lHeader)

# %% [raw]
# {'Content-Type': 'application/json', 'Content-Length': '3384', 'Connection': 'keep-alive', 'Date': 'Tue, 28 May 2024 06:49:09 GMT', 'Ratelimit-Policy': '3;w=60', 'Cache-Control': 'public, max-age=900', 'Content-Encoding': 'gzip', 'Ratelimit-Limit': '3', 'Ratelimit-Remaining': '2', 'Ratelimit-Reset': '60', 'Apigw-Requestid': 'YeCv2hvnIAMEaIQ=', 'Vary': 'Accept-Encoding', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 9eeb782e1dfe33bcf7bdffc7307e8fb4.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'BOM78-P7', 'X-Amz-Cf-Id': 'OIsI_kP9MOtyAjOkgL5nKisT2P-mMyTvNv43fW3ab0Hzcl1OpiFf8g==', 'Age': '73'}

# %%
print(f'Content-Type = {lHeader["Content-Type"]}')

print(f'Date = {lHeader["Date"]}')

# %% [raw]
# Content-Type = application/json
# Date = Tue, 28 May 2024 06:49:09 GMT

# %%
userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
aAuth = ("name","Afghanistan")

type(aAuth)

# %%
tuple

# %%
authResp = rq.get(url, auth=aAuth)
authResp

# %% [raw]
# <Response [200]>

# %%
authResp.json()

# %% [raw]
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': '>100'},
#  'results': [{'code': 'AF',
#    'name': 'Afghanistan',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 22:30:00+00',
#    'lastUpdated': '2021-08-16 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 23640,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'DZ',
#    'name': 'Algeria',
#    'locations': 1,
#    'firstUpdated': '2019-06-15 22:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 38663,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AQ',
#    'name': 'Antarctica',
#    'locations': 2,
#    'firstUpdated': '2018-11-30 11:00:00+00',
#    'lastUpdated': '2021-02-04 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 9180,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'AR',
#    'name': 'Argentina',
#    'locations': 16,
#    'firstUpdated': '2016-01-01 03:00:00+00',
#    'lastUpdated': '2024-05-29 03:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 286910,
#    'cities': 1,
#    'sources': 6},
#   {'code': 'AM',
#    'name': 'Armenia',
#    'locations': 1,
#    'firstUpdated': '2022-11-14 08:00:00+00',
#    'lastUpdated': '2023-06-15 11:00:00+00',
#    'parameters': ['pm25'],
#    'count': 1284,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AU',
#    'name': 'Australia',
#    'locations': 244,
#    'firstUpdated': '2016-01-28 19:00:00+00',
#    'lastUpdated': '2024-05-28 13:54:09+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13877317,
#    'cities': 55,
#    'sources': 10},
#   {'code': 'AT',
#    'name': 'Austria',
#    'locations': 374,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13408904,
#    'cities': 162,
#    'sources': 4},
#   {'code': 'AZ',
#    'name': 'Azerbaijan',
#    'locations': 1,
#    'firstUpdated': '2022-06-23 12:00:00+00',
#    'lastUpdated': '2024-05-28 05:00:00+00',
#    'parameters': ['pm25'],
#    'count': 12789,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BD',
#    'name': 'Bangladesh',
#    'locations': 4,
#    'firstUpdated': '2016-03-10 22:00:00+00',
#    'lastUpdated': '2024-05-28 05:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 139555,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'BE',
#    'name': 'Belgium',
#    'locations': 173,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4759104,
#    'cities': 77,
#    'sources': 6},
#   {'code': 'BZ',
#    'name': 'Belize',
#    'locations': 1,
#    'firstUpdated': '2023-03-19 20:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 7958,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BA',
#    'name': 'Bosnia and Herz.',
#    'locations': 47,
#    'firstUpdated': '2016-04-26 21:30:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1359930,
#    'cities': 23,
#    'sources': 7},
#   {'code': 'BR',
#    'name': 'Brazil',
#    'locations': 75,
#    'firstUpdated': '2017-07-01 00:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100',
#     'voc'],
#    'count': 3056064,
#    'cities': 39,
#    'sources': 5},
#   {'code': 'BG',
#    'name': 'Bulgaria',
#    'locations': 105,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-28 07:09:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 126712998,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'CA',
#    'name': 'Canada',
#    'locations': 365,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-28 07:06:13.349+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 18319262,
#    'cities': 18,
#    'sources': 5},
#   {'code': 'TD',
#    'name': 'Chad',
#    'locations': 1,
#    'firstUpdated': '2020-08-02 20:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 28989,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CL',
#    'name': 'Chile',
#    'locations': 154,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10829472,
#    'cities': 61,
#    'sources': 2},
#   {'code': 'CN',
#    'name': 'China',
#    'locations': 1873,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 170586062,
#    'cities': 18,
#    'sources': 19},
#   {'code': 'CO',
#    'name': 'Colombia',
#    'locations': 60,
#    'firstUpdated': '2016-03-17 15:00:00+00',
#    'lastUpdated': '2024-05-28 07:05:13.939+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2415822,
#    'cities': 10,
#    'sources': 5},
#   {'code': 'CR',
#    'name': 'Costa Rica',
#    'locations': 1,
#    'firstUpdated': '2019-10-28 18:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 33113,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CI',
#    'name': "Côte d'Ivoire",
#    'locations': 1,
#    'firstUpdated': '2020-03-15 21:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29730,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HR',
#    'name': 'Croatia',
#    'locations': 27,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1502425,
#    'cities': 16,
#    'sources': 3},
#   {'code': 'CY',
#    'name': 'Cyprus',
#    'locations': 11,
#    'firstUpdated': '2020-04-20 16:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 647897,
#    'cities': 11,
#    'sources': 2},
#   {'code': 'CZ',
#    'name': 'Czechia',
#    'locations': 124,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 11828344,
#    'cities': 72,
#    'sources': 4},
#   {'code': 'CD',
#    'name': 'Dem. Rep. Congo',
#    'locations': 1,
#    'firstUpdated': '2022-06-16 16:00:00+00',
#    'lastUpdated': '2024-05-04 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 3794,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'DK',
#    'name': 'Denmark',
#    'locations': 15,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm10',
#     'pm25',
#     'so2',
#     'temperature'],
#    'count': 1045087,
#    'cities': 9,
#    'sources': 3},
#   {'code': 'EC',
#    'name': 'Ecuador',
#    'locations': 10,
#    'firstUpdated': '2020-12-29 05:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 93265,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'EG',
#    'name': 'Egypt',
#    'locations': 2,
#    'firstUpdated': '2022-06-20 18:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 10862,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'EE',
#    'name': 'Estonia',
#    'locations': 7,
#    'firstUpdated': '2020-04-20 20:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 256687,
#    'cities': 5,
#    'sources': 1},
#   {'code': 'ET',
#    'name': 'Ethiopia',
#    'locations': 3,
#    'firstUpdated': '2016-08-18 22:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 113762,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'FI',
#    'name': 'Finland',
#    'locations': 81,
#    'firstUpdated': '2016-12-10 19:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 4440298,
#    'cities': 32,
#    'sources': 2},
#   {'code': 'FR',
#    'name': 'France',
#    'locations': 793,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-28 07:02:31.317+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 46324566,
#    'cities': 418,
#    'sources': 8},
#   {'code': 'GA',
#    'name': 'Gabon',
#    'locations': 1,
#    'firstUpdated': '2021-10-06 12:00:00+00',
#    'lastUpdated': '2022-02-27 19:00:00+00',
#    'parameters': ['pm25'],
#    'count': 2828,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'GM',
#    'name': 'Gambia',
#    'locations': 1,
#    'firstUpdated': '2022-10-20 01:00:00+00',
#    'lastUpdated': '2023-09-15 23:03:55.489+00',
#    'parameters': ['no2', 'pm1', 'pm10', 'pm25'],
#    'count': 12354,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'DE',
#    'name': 'Germany',
#    'locations': 511,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 24023152,
#    'cities': 291,
#    'sources': 4},
#   {'code': 'GH',
#    'name': 'Ghana',
#    'locations': 12,
#    'firstUpdated': '2020-05-01 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 1168515,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'GR',
#    'name': 'Greece',
#    'locations': 52,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-28 07:09:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 7385863,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'GT',
#    'name': 'Guatemala',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 21:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 96021,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'GN',
#    'name': 'Guinea',
#    'locations': 1,
#    'firstUpdated': '2020-05-01 02:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 28397,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HU',
#    'name': 'Hungary',
#    'locations': 97,
#    'firstUpdated': '2016-12-12 14:00:00+00',
#    'lastUpdated': '2024-05-28 23:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5689960,
#    'cities': 64,
#    'sources': 3},
#   {'code': 'IS',
#    'name': 'Iceland',
#    'locations': 24,
#    'firstUpdated': '2020-02-28 01:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 823645,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'IN',
#    'name': 'India',
#    'locations': 421,
#    'firstUpdated': '2016-01-30 00:30:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 42137301,
#    'cities': 6,
#    'sources': 10},
#   {'code': 'ID',
#    'name': 'Indonesia',
#    'locations': 12,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 138415,
#    'cities': 2,
#    'sources': 6},
#   {'code': 'IQ',
#    'name': 'Iraq',
#    'locations': 5,
#    'firstUpdated': '2019-03-10 16:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 71152,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'IE',
#    'name': 'Ireland',
#    'locations': 45,
#    'firstUpdated': '2016-02-27 21:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1690244,
#    'cities': 5,
#    'sources': 4},
#   {'code': 'IL',
#    'name': 'Israel',
#    'locations': 111,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2021-11-19 09:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 19575369,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'IT',
#    'name': 'Italy',
#    'locations': 745,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25533985,
#    'cities': 586,
#    'sources': 8},
#   {'code': 'JP',
#    'name': 'Japan',
#    'locations': 1539,
#    'firstUpdated': '2023-07-14 17:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'pm25', 'so2', 'temperature'],
#    'count': 37759182,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'JO',
#    'name': 'Jordan',
#    'locations': 5,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 648734,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KZ',
#    'name': 'Kazakhstan',
#    'locations': 40,
#    'firstUpdated': '2018-07-27 16:00:00+00',
#    'lastUpdated': '2024-05-28 07:06:58.926+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 139687,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'KE',
#    'name': 'Kenya',
#    'locations': 6,
#    'firstUpdated': '2018-04-21 00:00:00+00',
#    'lastUpdated': '2024-05-28 06:59:59.622+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 20985,
#    'cities': 1,
#    'sources': 4},
#   {'code': 'XK',
#    'name': 'Kosovo',
#    'locations': 24,
#    'firstUpdated': '2016-04-08 20:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 608825,
#    'cities': 12,
#    'sources': 4},
#   {'code': 'KW',
#    'name': 'Kuwait',
#    'locations': 1,
#    'firstUpdated': '2017-02-17 21:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54874,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'KG',
#    'name': 'Kyrgyzstan',
#    'locations': 47,
#    'firstUpdated': '2019-03-08 20:00:00+00',
#    'lastUpdated': '2024-05-28 07:07:03.139+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 177714,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'LA',
#    'name': 'Laos',
#    'locations': 9,
#    'firstUpdated': '2021-04-29 19:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 226767,
#    'cities': 4,
#    'sources': 3},
#   {'code': 'LV',
#    'name': 'Latvia',
#    'locations': 13,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 427374,
#    'cities': 5,
#    'sources': 2},
#   {'code': 'LT',
#    'name': 'Lithuania',
#    'locations': 17,
#    'firstUpdated': '2017-09-21 23:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 919133,
#    'cities': 13,
#    'sources': 2},
#   {'code': 'LU',
#    'name': 'Luxembourg',
#    'locations': 12,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 869159,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'MK',
#    'name': 'Macedonia',
#    'locations': 28,
#    'firstUpdated': '2016-12-10 20:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2965583,
#    'cities': 6,
#    'sources': 2},
#   {'code': 'MG',
#    'name': 'Madagascar',
#    'locations': 1,
#    'firstUpdated': '2020-12-22 06:00:00+00',
#    'lastUpdated': '2024-05-28 05:00:00+00',
#    'parameters': ['pm25'],
#    'count': 21879,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MY',
#    'name': 'Malaysia',
#    'locations': 11,
#    'firstUpdated': '2016-04-05 09:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 114791,
#    'cities': 4,
#    'sources': 4},
#   {'code': 'ML',
#    'name': 'Mali',
#    'locations': 1,
#    'firstUpdated': '2020-03-16 05:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 25471,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MX',
#    'name': 'Mexico',
#    'locations': 237,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10839235,
#    'cities': 111,
#    'sources': 4},
#   {'code': 'MD',
#    'name': 'Moldova',
#    'locations': 2,
#    'firstUpdated': '2020-04-20 19:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['no2', 'pm10', 'pm25', 'so2'],
#    'count': 35331,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'MN',
#    'name': 'Mongolia',
#    'locations': 44,
#    'firstUpdated': '2016-01-30 00:15:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2358919,
#    'cities': 22,
#    'sources': 3},
#   {'code': 'ME',
#    'name': 'Montenegro',
#    'locations': 9,
#    'firstUpdated': '2022-03-24 14:00:00+00',
#    'lastUpdated': '2024-03-19 22:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 273080,
#    'cities': 7,
#    'sources': 1},
#   {'code': 'MA',
#    'name': 'Morocco',
#    'locations': 2,
#    'firstUpdated': '2024-04-04 10:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 8100,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'MZ',
#    'name': 'Mozambique',
#    'locations': 1,
#    'firstUpdated': '2024-01-18 18:00:00+00',
#    'lastUpdated': '2024-01-22 16:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 137,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MM',
#    'name': 'Myanmar',
#    'locations': 5,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 319649,
#    'cities': 3,
#    'sources': 4},
#   {'code': 'NP',
#    'name': 'Nepal',
#    'locations': 4,
#    'firstUpdated': '2017-03-02 23:15:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 222055,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'NL',
#    'name': 'Netherlands',
#    'locations': 98,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13075257,
#    'cities': 50,
#    'sources': 4},
#   {'code': 'NZ',
#    'name': 'New Zealand',
#    'locations': 12,
#    'firstUpdated': '2023-03-31 15:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 96414,
#    'cities': 8,
#    'sources': 2},
#   {'code': 'NG',
#    'name': 'Nigeria',
#    'locations': 5,
#    'firstUpdated': '2019-04-26 08:00:00+00',
#    'lastUpdated': '2024-05-28 07:06:07.464+00',
#    'parameters': ['pm25'],
#    'count': 23160,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KP',
#    'name': 'North Korea',
#    'locations': 4,
#    'firstUpdated': '2024-03-20 08:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 28821,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'NO',
#    'name': 'Norway',
#    'locations': 354,
#    'firstUpdated': '2016-12-02 10:00:00+00',
#    'lastUpdated': '2024-05-28 07:09:00+00',
#    'parameters': ['bc',
#     'co',
#     'co2',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 36125561,
#    'cities': 27,
#    'sources': 5},
#   {'code': 'PK',
#    'name': 'Pakistan',
#    'locations': 6,
#    'firstUpdated': '2019-05-22 22:00:00+00',
#    'lastUpdated': '2024-05-28 07:06:22.758+00',
#    'parameters': ['pm25'],
#    'count': 168020,
#    'cities': 4,
#    'sources': 5},
#   {'code': 'PS',
#    'name': 'Palestine',
#    'locations': 9,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2019-04-03 21:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'so2'],
#    'count': 1449100,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'PY',
#    'name': 'Paraguay',
#    'locations': 1,
#    'firstUpdated': '2023-10-02 19:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['pm25'],
#    'count': 5046,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'PE',
#    'name': 'Peru',
#    'locations': 46,
#    'firstUpdated': '2016-03-04 17:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2301330,
#    'cities': 21,
#    'sources': 5},
#   {'code': 'PH',
#    'name': 'Philippines',
#    'locations': 5,
#    'firstUpdated': '2023-09-06 20:00:00+00',
#    'lastUpdated': '2024-05-28 07:04:13.585+00',
#    'parameters': ['pm25', 'temperature'],
#    'count': 12321,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'PL',
#    'name': 'Poland',
#    'locations': 330,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['bc',
#     'co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25797813,
#    'cities': 197,
#    'sources': 5},
#   {'code': 'PT',
#    'name': 'Portugal',
#    'locations': 70,
#    'firstUpdated': '2017-05-11 08:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6848009,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'PR',
#    'name': 'Puerto Rico',
#    'locations': 5,
#    'firstUpdated': '2016-05-04 11:00:00+00',
#    'lastUpdated': '2024-05-28 05:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 99586,
#    'cities': 2,
#    'sources': 1},
#   {'code': 'QA',
#    'name': 'Qatar',
#    'locations': 1,
#    'firstUpdated': '2022-04-11 14:00:00+00',
#    'lastUpdated': '2023-11-30 08:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 16513,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'RO',
#    'name': 'Romania',
#    'locations': 318,
#    'firstUpdated': '2020-04-19 21:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5244309,
#    'cities': 109,
#    'sources': 4},
#   {'code': 'RU',
#    'name': 'Russia',
#    'locations': 54,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 560673,
#    'cities': 2,
#    'sources': 5},
#   {'code': 'RW',
#    'name': 'Rwanda',
#    'locations': 2,
#    'firstUpdated': '2020-12-28 22:45:00+00',
#    'lastUpdated': '2024-05-14 00:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25'],
#    'count': 126004,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'SA',
#    'name': 'Saudi Arabia',
#    'locations': 5,
#    'firstUpdated': '2019-07-15 19:00:00+00',
#    'lastUpdated': '2024-05-28 05:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25', 'so2'],
#    'count': 21277,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'SN',
#    'name': 'Senegal',
#    'locations': 1,
#    'firstUpdated': '2023-09-05 08:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 7088,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'RS',
#    'name': 'Serbia',
#    'locations': 85,
#    'firstUpdated': '2017-09-22 09:00:00+00',
#    'lastUpdated': '2024-05-28 07:02:08.275+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'temperature'],
#    'count': 3298870,
#    'cities': 43,
#    'sources': 5},
#   {'code': 'SK',
#    'name': 'Slovakia',
#    'locations': 85,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-28 06:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 5925083,
#    'cities': 58,
#    'sources': 3},
#   {'code': 'SI',
#    'name': 'Slovenia',
#    'locations': 39,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 786760,
#    'cities': 26,
#    'sources': 3},
#   {'code': 'ZA',
#    'name': 'South Africa',
#    'locations': 200,
#    'firstUpdated': '2016-02-14 08:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4685719,
#    'cities': 36,
#    'sources': 4},
#   {'code': 'KR',
#    'name': 'South Korea',
#    'locations': 685,
#    'firstUpdated': '2020-10-12 06:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6147830,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'ES',
#    'name': 'Spain',
#    'locations': 738,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-28 07:09:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 44875637,
#    'cities': 352,
#    'sources': 7},
#   {'code': 'LK',
#    'name': 'Sri Lanka',
#    'locations': 1,
#    'firstUpdated': '2019-06-25 21:30:00+00',
#    'lastUpdated': '2024-05-27 07:30:00+00',
#    'parameters': ['pm25'],
#    'count': 21793,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'SD',
#    'name': 'Sudan',
#    'locations': 3,
#    'firstUpdated': '2020-05-14 14:00:00+00',
#    'lastUpdated': '2023-05-17 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54546,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'SE',
#    'name': 'Sweden',
#    'locations': 170,
#    'firstUpdated': '2016-12-02 11:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2532616,
#    'cities': 53,
#    'sources': 5},
#   {'code': 'CH',
#    'name': 'Switzerland',
#    'locations': 51,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 3286006,
#    'cities': 13,
#    'sources': 3},
#   {'code': 'TW',
#    'name': 'Taiwan',
#    'locations': 91,
#    'firstUpdated': '2016-12-20 19:00:00+00',
#    'lastUpdated': '2024-05-28 07:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 8372966,
#    'cities': 17,
#    'sources': 2}]}
